# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/nivyana boruah/Downloads/traffic.csv/traffic.csv")
df.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
df['DateTime']= pd.to_datetime(df['DateTime'])

df['hour']= df['DateTime'].dt.hour
df['day']= df['DateTime'].dt.dayofweek

# %%
df= df.drop("ID",axis=1)
df.head()
# Out:
#              DateTime  Junction  Vehicles  hour  day
# 0 2015-11-01 00:00:00         1        15     0    6
# 1 2015-11-01 01:00:00         1        13     1    6
# 2 2015-11-01 02:00:00         1        10     2    6
# 3 2015-11-01 03:00:00         1         7     3    6
# 4 2015-11-01 04:00:00         1         9     4    6

# %%
def class_congestion(x):
    if x<10:
        return "Low"
    elif x <20:
        return "Medium"
    else:
        return "High"

df['congestion']= df['Vehicles'].apply(class_congestion)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['congestion']= le.fit_transform(df['congestion'])

# %%
X = df[['hour', 'day','Junction', 'Vehicles']]
y = df['congestion']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
# !pip install networkx

# %%
import networkx as nx

G = nx.Graph()

G.add_edge(1,2,weight=5)
G.add_edge(2,3,weight=7)
G.add_edge(1,3,weight=15)

print(nx.dijkstra_path(G,1,3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import networkx as nx
#       3 G = nx.Graph()
#       5 G.add_edge(1,2,weight=5)
#
# ModuleNotFoundError: No module named 'networkx'

# %%
import matplotlib.pyplot as plt

df.groupby('hour')['Vehicles'].mean().plot()
plt.title("Traffic vs Hour")
plt.xlabel("Hour")
plt.ylabel("Avg Vehicles")
plt.show()
