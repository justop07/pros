# %%
from pyspark.sql import SparkSession
import time

spark = SparkSession.builder.appName("SparkTest").getOrCreate()

start = time.time()

df = spark.read.csv("students.csv", header=True, inferSchema=True)

df.groupBy("subject").avg("marks").show()

end = time.time()

print("Spark Execution Time:", end - start)
# Out:
# +-------+----------+
# |subject|avg(marks)|
# +-------+----------+
# |Science|      72.5|
# |   Math|      88.5|
# |English|      88.0|
# +-------+----------+
#
# Spark Execution Time: 8.147229433059692

# %%
from pyflink.table import EnvironmentSettings, TableEnvironment
import time

env_settings = EnvironmentSettings.in_batch_mode()
t_env = TableEnvironment.create(env_settings)

start = time.time()

t_env.execute_sql("""
CREATE TABLE students (
    name STRING,
    subject STRING,
    marks INT,
    age INT
) WITH (
    'connector' = 'filesystem',
    'path' = 'students.csv',
    'format' = 'csv'
)
""")

result = t_env.sql_query("""
SELECT subject, AVG(marks)
FROM students
GROUP BY subject
""")

result.execute().print()

end = time.time()

print("Flink Execution Time:", end - start)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       2 import time
#       4 env_settings = EnvironmentSettings.in_batch_mode()
# ----> 5 t_env = TableEnvironment.create(env_settings)
#       7 start = time.time()
#       9 t_env.execute_sql("""
#      10 CREATE TABLE students (
#      11     name STRING,
#    (...)
#      19 )
#      20 """)
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\pyflink\table\table_environment.py:126, in TableEnvironment.create(environment_settings)
#     123     raise TypeError("argument should be EnvironmentSettings or Configuration")
#     125 j_tenv = gateway.jvm.TableEnvironment.create(environment_settings._j_environment_settings)
# --> 126 return TableEnvironment(j_tenv)
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\pyflink\table\table_environment.py:105, in TableEnvironment.__init__(self, j_tenv, serializer)
#     103 self._set_python_executable_for_local_executor()
#     104 self._config_chaining_optimization()
# --> 105 self._open()
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\pyflink\table\table_environment.py:1750, in TableEnvironment._open(self)
#    1748 if python_worker_execution_mode is None:
#    1749     if is_local_deployment(get_j_env_configuration(self._get_j_env())):
# -> 1750         startup_loopback_server()
#    1751 elif python_worker_execution_mode == 'loopback':
#    1752     if is_local_deployment(get_j_env_configuration(self._get_j_env())):
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\pyflink\table\table_environment.py:1741, in TableEnvironment._open.<locals>.startup_loopback_server()
#    1740 def startup_loopback_server():
# -> 1741     from pyflink.fn_execution.beam.beam_worker_pool_service import \
#    1742         BeamFnLoopbackWorkerPoolServicer
#    1743     self.get_config().set("python.loopback-server.address",
#    1744                           BeamFnLoopbackWorkerPoolServicer().start())
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\pyflink\fn_execution\beam\beam_worker_pool_service.py:40
#      36 from apache_beam.portability.api.org.apache.beam.model.fn_execution.v1.beam_provision_api_pb2 \
#      37     import GetProvisionInfoRequest
#      38 from apache_beam.portability.api.org.apache.beam.model.fn_execution.v1.beam_provision_api_pb2_grpc \
#      39     import ProvisionServiceStub
# ---> 40 from apache_beam.runners.worker import sdk_worker_main
#      41 from apache_beam.runners.worker.log_handler import FnApiLogRecordHandler
#      42 from apache_beam.runners.worker.sdk_worker import SdkHarness
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\apache_beam\runners\worker\sdk_worker_main.py:33
#      30 from google.protobuf import text_format  # type: ignore # not in typeshed
#      32 from apache_beam.internal import pickler
# ---> 33 from apache_beam.io import filesystems
#      34 from apache_beam.options.pipeline_options import DebugOptions
#      35 from apache_beam.options.pipeline_options import GoogleCloudOptions
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\apache_beam\__init__.py:88
#      85 import apache_beam.internal.pickler
#      87 from apache_beam import coders
# ---> 88 from apache_beam import io
#      89 from apache_beam import metrics
#      90 from apache_beam import typehints
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\apache_beam\io\__init__.py:28
#      26 from apache_beam.io.iobase import Writer
#      27 from apache_beam.io.mongodbio import *
# ---> 28 from apache_beam.io.parquetio import *
#      29 from apache_beam.io.textio import *
#      30 from apache_beam.io.tfrecordio import *
#
# File ~\anaconda3\envs\ml_env\lib\site-packages\apache_beam\io\parquetio.py:35
#      31 # pytype: skip-file
#      33 from functools import partial
# ---> 35 from pkg_resources import parse_version
#      37 from apache_beam.io import filebasedsink
#      38 from apache_beam.io import filebasedsource
#
# ModuleNotFoundError: No module named 'pkg_resources'
