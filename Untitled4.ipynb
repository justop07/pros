# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27017")
db=client["college"]
students=db['students']

# %%
students.insert_one({
    "id":"S101",
    'name':'Nivyana',
    'age':21,
    "course":"AIML"
})
# Out:
# InsertOneResult(ObjectId('69da25feece4e56ebbb5913e'), acknowledged=True)

# %%
for s in students.find():
    print(s)
# Out:
# {'_id': ObjectId('69da25feece4e56ebbb5913e'), 'id': 'S101', 'name': 'Nivyana', 'age': 21, 'course': 'AIML'}

# %%
students.find({"course": "AIML"})

# %%
students.update_one(
    {"id":"S101"},
    {"$set":}
)
